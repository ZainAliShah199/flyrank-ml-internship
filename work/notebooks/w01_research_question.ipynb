# %% [markdown]
# <a href="https://colab.research.google.com/github/ZainAliShah199/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ZainAliShah199/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# **Lane:** Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because it focuses on identifying which pages should be prioritized for content updates. The starter notebooks showed that machine learning can rank pages more effectively than a simple rule-based approach. This project can help content teams focus their efforts on pages that are most likely to benefit from a refresh, improving decision-making and making better use of limited time and resources.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Research Question:** Which content pages should be prioritized for review using search performance and engagement signals?
#
# **Unit of analysis:** Individual content pages.
#
# **Decision:** Decide which pages should be reviewed first.
#
# **Who acts on it:** SEO specialists, content managers, and marketing teams.
#
# **Action:** Refresh, improve, or monitor the selected pages.
#
# **Cost of a wrong recommendation:** If the wrong pages are prioritized, valuable pages may continue to decline while time is wasted updating pages that do not need attention. This reduces team efficiency and may negatively affect search performance.
#
# Machine learning can help discover patterns in historical search data that support better prioritization decisions than relying only on manual rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data
#
# The starter dataset contains 30,000 pages with multiple search and engagement features. I will use the statistics generated below to better understand the dataset and support why this lane is worth exploring. The number of declining pages and the average click-through rate show that page performance varies enough to make content prioritization an important problem.

# %%
import os, sys, subprocess

REPO_DIR = "flyrank-ml-internship-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run(
        ["git", "clone", "--depth", "1",
         "https://github.com/ZainAliShah199/flyrank-ml-internship",
         REPO_DIR],
        check=True
    )

os.chdir(REPO_DIR)

print("Working directory:", os.getcwd())
# Out:
# Working directory: /flyrank-ml-internship-starter/flyrank-ml-internship-starter

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total rows:", len(df))
print("Total columns:", len(df.columns))

declining = (df["trend_direction"] == "down").sum()
print("Declining pages:", declining)

print("Average CTR:", round(df["ctr"].mean(), 3))

print("Average impressions:", round(df["impressions_90d"].mean(), 2))
# Out:
# Total rows: 30000
# Total columns: 44
# Declining pages: 16262
# Average CTR: 0.511
# Average impressions: 5200.37

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project provides decision support by identifying observed patterns in search and engagement data. The results can help prioritize pages for review, but they cannot prove that refreshing a page will improve rankings or traffic. The analysis is directional and should support human decision-making rather than replace it. This project does not predict Google's algorithms or establish causal relationships.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
